# %%
! pip install torch-directml
# Out:
# Collecting torch-directml
#   Using cached torch_directml-0.2.5.dev240914-cp39-cp39-win_amd64.whl.metadata (6.2 kB)
# Collecting torch==2.4.1 (from torch-directml)
#   Using cached torch-2.4.1-cp39-cp39-win_amd64.whl.metadata (27 kB)
# Collecting torchvision==0.19.1 (from torch-directml)
#   Using cached torchvision-0.19.1-cp39-cp39-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (4.15.0)
# Requirement already satisfied: sympy in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.19.1->torch-directml) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.19.1->torch-directml) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\.conda\.conda\lib\site-packages (from jinja2->torch==2.4.1->torch-directml) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\.conda\.conda\lib\site-packages (from sympy->torch==2.4.1->torch-directml) (1.3.0)
# Using cached torch_directml-0.2.5.dev240914-cp39-cp39-win_amd64.whl (9.0 MB)
# Using cached torch-2.4.1-cp39-cp39-win_amd64.whl (199.3 MB)
# Using cached torchvision-0.19.1-cp39-cp39-win_amd64.whl (1.3 MB)
# Installing collected packages: torch, torchvision, torch-directml
#
#   Attempting uninstall: torch
#
#     Found existing installation: torch 2.1.0
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#     Uninstalling torch-2.1.0:
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#       Successfully uninstalled torch-2.1.0
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#   Attempting uninstall: torchvision
#    ---------------------------------------- 0/3 [torch]
#     Found existing installation: torchvision 0.16.0
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#     Uninstalling torchvision-0.16.0:
#    ------------- -------------------------- 1/3 [torchvision]
#       Successfully uninstalled torchvision-0.16.0
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ---------------------------------------- 3/3 [torch-directml]
#
# Successfully installed torch-2.4.1 torch-directml-0.2.5.dev240914 torchvision-0.19.1
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install torch-directml

import torch
import torch_directml 

# Select your AMD GPU through DirectML
device = torch_directml.device()

# Test GPU
x = torch.randn(1024, 1024, device=device)
y = torch.randn(1024, 1024, device=device)

z = x @ y  # Runs on AMD GPU
print("Device:", z.device)
# Out:
# Requirement already satisfied: torch-directml in c:\users\hp\.conda\.conda\lib\site-packages (0.1.13.1.dev230301)
# Requirement already satisfied: torch==1.13.1 in c:\users\hp\.conda\.conda\lib\site-packages (from torch-directml) (1.13.1)
# Requirement already satisfied: torchvision==0.14.1 in c:\users\hp\.conda\.conda\lib\site-packages (from torch-directml) (0.14.1)
# Requirement already satisfied: typing-extensions in c:\users\hp\.conda\.conda\lib\site-packages (from torch==1.13.1->torch-directml) (4.15.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.14.1->torch-directml) (1.26.4)
# Requirement already satisfied: requests in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.14.1->torch-directml) (2.32.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.14.1->torch-directml) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 10
#       7 device = torch_directml.device()
#       9 # Test GPU
# ---> 10 x = torch.randn(1024, 1024, device=device)
#      11 y = torch.randn(1024, 1024, device=device)
#      13 z = x @ y  # Runs on AMD GPU
#
# ModuleNotFoundError: No module named 'torch.privateuseone'

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.1+cpu

# %%
# !pip uninstall torch torchvision torchaudio torch-directml -y
# Out:
# Found existing installation: torch 1.13.1
# Uninstalling torch-1.13.1:
#   Successfully uninstalled torch-1.13.1
# Found existing installation: torchvision 0.14.1
# Uninstalling torchvision-0.14.1:
#   Successfully uninstalled torchvision-0.14.1
# Found existing installation: torch-directml 0.1.13.1.dev230301
# Uninstalling torch-directml-0.1.13.1.dev230301:
#   Successfully uninstalled torch-directml-0.1.13.1.dev230301
# WARNING: Skipping torchaudio as it is not installed.

# %%
! pip install --upgrade torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.8.0-cp39-cp39-win_amd64.whl.metadata (30 kB)
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp39-cp39-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.8.0-cp39-cp39-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\.conda\.conda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\.conda\.conda\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.8.0-cp39-cp39-win_amd64.whl (241.2 MB)
#    ---------------------------------------- 0.0/241.2 MB ? eta -:--:--
#
6 MB/s eta 0:00:07
#    ----------------------------------- ---- 213.1/241.2 MB 4.5 MB/s eta 0:00:07
#    ----------------------------------- ---- 214.2/241.2 MB 4.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 215.2/241.2 MB 4.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 216.3/241.2 MB 4.5 MB/s eta 0:00:06
#    ------------------------------------ --- 217.3/241.2 MB 4.5 MB/s eta 0:00:06
#    ------------------------------------ --- 218.4/241.2 MB 4.5 MB/s eta 0:00:06
#    ------------------------------------ --- 219.2/241.2 MB 4.5 MB/s eta 0:00:05
#    ------------------------------------ --- 220.2/241.2 MB 4.6 MB/s eta 0:00:05
#    ------------------------------------ --- 221.2/241.2 MB 4.6 MB/s eta 0:00:05
#    ------------------------------------ --- 222.3/241.2 MB 4.6 MB/s eta 0:00:05
#    ------------------------------------- -- 223.3/241.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------------------- -- 224.1/241.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------------------- -- 225.4/241.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------------------- -- 226.5/241.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------------------- -- 227.5/241.2 MB 4.6 MB/s eta 0:00:03
#    ------------------------------------- -- 228.3/241.2 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 229.4/241.2 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 230.2/241.2 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 231.2/241.2 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 232.3/241.2 MB 4.6 MB/s eta 0:00:02
#    -------------------------------------- - 233.3/241.2 MB 4.6 MB/s eta 0:00:02
#    -------------------------------------- - 234.4/241.2 MB 4.6 MB/s eta 0:00:02
#    -------------------------------------- - 235.1/241.2 MB 4.6 MB/s eta 0:00:02
#    ---------------------------------------  236.2/241.2 MB 4.6 MB/s eta 0:00:02
#    ---------------------------------------  237.0/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  238.0/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  238.8/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  239.9/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  240.9/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 241.2/241.2 MB 4.5 MB/s eta 0:00:00
# Downloading torchvision-0.23.0-cp39-cp39-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.5 MB/s eta 0:00:00
# Downloading torchaudio-2.8.0-cp39-cp39-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------- ----------------------- 1.0/2.5 MB 5.0 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 4.8 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.8.0 torchaudio-2.8.0 torchvision-0.23.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install torch-directml
# Out:
# Collecting torch-directml
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.8.0 requires torch==2.8.0, but you have torch 2.4.1 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached torch_directml-0.2.5.dev240914-cp39-cp39-win_amd64.whl.metadata (6.2 kB)
# Collecting torch==2.4.1 (from torch-directml)
#   Using cached torch-2.4.1-cp39-cp39-win_amd64.whl.metadata (27 kB)
# Collecting torchvision==0.19.1 (from torch-directml)
#   Using cached torchvision-0.19.1-cp39-cp39-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (4.15.0)
# Requirement already satisfied: sympy in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.19.1->torch-directml) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.19.1->torch-directml) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\.conda\.conda\lib\site-packages (from jinja2->torch==2.4.1->torch-directml) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\.conda\.conda\lib\site-packages (from sympy->torch==2.4.1->torch-directml) (1.3.0)
# Using cached torch_directml-0.2.5.dev240914-cp39-cp39-win_amd64.whl (9.0 MB)
# Using cached torch-2.4.1-cp39-cp39-win_amd64.whl (199.3 MB)
# Using cached torchvision-0.19.1-cp39-cp39-win_amd64.whl (1.3 MB)
# Installing collected packages: torch, torchvision, torch-directml
#
#   Attempting uninstall: torch
#
#     Found existing installation: torch 2.8.0
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#     Uninstalling torch-2.8.0:
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#       Successfully uninstalled torch-2.8.0
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#   Attempting uninstall: torchvision
#    ---------------------------------------- 0/3 [torch]
#     Found existing installation: torchvision 0.23.0
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#     Uninstalling torchvision-0.23.0:
#    ------------- -------------------------- 1/3 [torchvision]
#       Successfully uninstalled torchvision-0.23.0
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torch-directml]
#    ---------------------------------------- 3/3 [torch-directml]
#
# Successfully installed torch-2.4.1 torch-directml-0.2.5.dev240914 torchvision-0.19.1

# %%
import torch
import torch_directml

# Select AMD GPU
device = torch_directml.device()

# Create tensors on GPU
x = torch.randn(1024, 1024, device=device)
y = torch.randn(1024, 1024, device=device)
z = x @ y

print("Device used:", z.device)  # Should show DirectML with your AMD GPU
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 8
#       5 device = torch_directml.device()
#       7 # Create tensors on GPU
# ----> 8 x = torch.randn(1024, 1024, device=device)
#       9 y = torch.randn(1024, 1024, device=device)
#      10 z = x @ y
#
# ModuleNotFoundError: No module named 'torch.privateuseone'

# %%
! pip install torch-directml==0.1.13
# Out:
# ERROR: Could not find a version that satisfies the requirement torch-directml==0.1.13 (from versions: 0.1.13.dev221206, 0.1.13.dev221216, 0.1.13.1.dev230119, 0.1.13.1.dev230301, 0.1.13.1.dev230413, 0.2.0.dev230426, 0.2.1.dev240521, 0.2.2.dev240614, 0.2.3.dev240715, 0.2.4.dev240815, 0.2.4.dev240913, 0.2.5.dev240914)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for torch-directml==0.1.13

# %%
! pip install torch-directml==0.1.13.1.dev230301
# Out:
# Collecting torch-directml==0.1.13.1.dev230301
#   Downloading torch_directml-0.1.13.1.dev230301-cp39-cp39-win_amd64.whl.metadata (6.2 kB)
# Collecting torch==1.13.1 (from torch-directml==0.1.13.1.dev230301)
#   Downloading torch-1.13.1-cp39-cp39-win_amd64.whl.metadata (23 kB)
# Collecting torchvision==0.14.1 (from torch-directml==0.1.13.1.dev230301)
#   Downloading torchvision-0.14.1-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions in c:\users\hp\.conda\.conda\lib\site-packages (from torch==1.13.1->torch-directml==0.1.13.1.dev230301) (4.15.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (1.26.4)
# Requirement already satisfied: requests in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (2.32.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\.conda\.conda\lib\site-packages (from requests->torchvision==0.14.1->torch-directml==0.1.13.1.dev230301) (2025.7.14)
# Downloading torch_directml-0.1.13.1.dev230301-cp39-cp39-win_amd64.whl (7.4 MB)
#    ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.4 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.4 MB 3.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.4 MB 3.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.4 MB 3.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.4 MB 1.1 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.1/7.4 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.4 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.4 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.4 MB 1.7 MB/s eta 0:00:04
#    --------------- ------------------------ 2.9/7.4 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.4/7.4 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 4.5/7.4 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.4 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.4 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.4 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.4 MB 1.9 MB/s eta 0:00:02
#    ------------------------------- -------- 5.8/7.4 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 6.6/7.4 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.4/7.4 MB 1.9 MB/s eta 0:00:00
# Downloading torch-1.13.1-cp39-cp39-win_amd64.whl (162.5 MB)
#    ---------------------------------------- 0.0/162.5 MB ? eta -:--:--
#    ---------------------------------------- 0.8/162.5 MB 4.8 MB/s eta 0:00:34
#    ---------------------------------------- 1.6/162.5 MB 4.0 MB/s eta 0:00:41
#     --------------------------------------- 2.4/162.5 MB 4.1 MB/s eta 0:00:40
#     --------------------------------------- 3.1/162.5 MB 4.0 MB/s eta 0:00:40
#    - -------------------------------------- 4.2/162.5 MB 4.1 MB/s eta 0:00:40
#    - -------------------------------------- 5.0/162.5 MB 4.0 MB/s eta 0:00:40
#    - -------------------------------------- 6.0/162.5 MB 4.1 MB/s eta 0:00:39
#    - -------------------------------------- 7.1/162.5 MB 4.2 MB/s eta 0:00:37
#    - -------------------------------------- 7.6/162.5 MB 4.3 MB/s eta 0:00:37
#    -- ------------------------------------- 8.1/162.5 MB 3.9 MB/s eta 0:00:40
#    -- ------------------------------------- 9.2/162.5 MB 4.0 MB/s eta 0:00:39
#    -- ------------------------------------- 10.0/162.5 MB 4.0 MB/s eta 0:00:39
#    -- ------------------------------------- 11.0/162.5 MB 4.0 MB/s eta 0:00:38
#    -- ------------------------------------- 11.8/162.5 MB 4.1 MB/s eta 0:00:38
#    --- ------------------------------------ 12.8/162.5 MB 4.1 MB/s eta 0:00:37
#    --- ------------------------------------ 13.6/162.5 MB 4.1 MB/s eta 0:00:37
#    --- ------------------------------------ 14.7/162.5 MB 4.1 MB/s eta 0:00:36
#    --- ------------------------------------ 15.5/162.5 MB 4.2 MB/s eta 0:00:36
#    ---- ----------------------------------- 16.5/162.5 MB 4.2 MB/s eta 0:00:36
#    ---- ----------------------------------- 17.6/162.5 MB 4.2 MB/s eta 0:00:35
#    ---- ----------------------------------- 18.4/162.5 MB 4.2 MB/s eta 0:00:35
#    ---- ----------------------------------- 19.4/162.5 MB 4.3 MB/s eta 0:00:34
#    ---- ----------------------------------- 20.2/162.5 MB 4.2 MB/s eta 0:00:34
#    ----- ---------------------------------- 21.0/162.5 MB 4.2 MB/s eta 0:00:34
#    ----- ---------------------------------- 21.8/162.5 MB 4.2 MB/s eta 0:00:34
#    ----- ----------------------------------
5 MB 3.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 144.4/162.5 MB 3.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 145.2/162.5 MB 3.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 146.0/162.5 MB 3.3 MB/s eta 0:00:06
#    ------------------------------------ --- 146.8/162.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------------------ --- 147.3/162.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------------------ --- 148.1/162.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------------------ --- 148.6/162.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------------------ --- 149.4/162.5 MB 3.3 MB/s eta 0:00:04
#    ------------------------------------ --- 149.9/162.5 MB 3.3 MB/s eta 0:00:04
#    ------------------------------------- -- 150.7/162.5 MB 3.3 MB/s eta 0:00:04
#    ------------------------------------- -- 151.3/162.5 MB 3.3 MB/s eta 0:00:04
#    ------------------------------------- -- 152.0/162.5 MB 3.3 MB/s eta 0:00:04
#    ------------------------------------- -- 152.6/162.5 MB 3.3 MB/s eta 0:00:04
#    ------------------------------------- -- 153.1/162.5 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------- -- 153.9/162.5 MB 3.3 MB/s eta 0:00:03
#    -------------------------------------- - 154.4/162.5 MB 3.3 MB/s eta 0:00:03
#    -------------------------------------- - 155.2/162.5 MB 3.3 MB/s eta 0:00:03
#    -------------------------------------- - 156.0/162.5 MB 3.3 MB/s eta 0:00:02
#    -------------------------------------- - 156.8/162.5 MB 3.3 MB/s eta 0:00:02
#    -------------------------------------- - 157.8/162.5 MB 3.3 MB/s eta 0:00:02
#    -------------------------------------- - 158.3/162.5 MB 3.3 MB/s eta 0:00:02
#    ---------------------------------------  159.4/162.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  160.2/162.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  161.0/162.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  161.7/162.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  162.3/162.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  162.3/162.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 162.5/162.5 MB 3.3 MB/s eta 0:00:00
# Downloading torchvision-0.14.1-cp39-cp39-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision, torch-directml
#
#   Attempting uninstall: torch
#
#     Found existing installation: torch 2.4.1
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#     Uninstalling torch-2.4.1:
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#       Successfully uninstalled torch-2.4.1
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\HP\.conda\.conda\Lib\site-packages\~~rch'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\HP\.conda\.conda\Lib\site-packages\~-rch_directml'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\MinGW\bin\pip-uninstall-n6p840o2'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#   Attempting uninstall: torchvision
#    ---------------------------------------- 0/3 [torch]
#     Found existing installation: torchvision 0.19.1
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#     Uninstalling torchvision-0.19.1:
#    ------------- -------------------------- 1/3 [torchvision]
#       Successfully uninstalled torchvision-0.19.1
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#   Attempting uninstall: torch-directml
#    ------------- -------------------------- 1/3 [torchvision]
#     Found existing installation: torch-directml 0.2.5.dev240914
#    ------------- -------------------------- 1/3 [torchvision]
#     Uninstalling torch-directml-0.2.5.dev240914:
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#       Successfully uninstalled torch-directml-0.2.5.dev240914
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    -------------------------- ------------- 2/3 [torch-directml]
#    ---------------------------------------- 3/3 [torch-directml]
#
# Successfully installed torch-1.13.1 torch-directml-0.1.13.1.dev230301 torchvision-0.14.1

# %%
# ----------------------------------------
# DIRECTML VERSION — SAME FEATURES, SAME MODEL
# ----------------------------------------

import os
import random
import numpy as np
from PIL import Image
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# Use DirectML (if installed)
try:
    import torch_directml
    device = torch_directml.device()
    print("Using DirectML:", device)
except:
    device = torch.device("cpu")
    print("DirectML not found, using CPU.")

# ------------------------------
# USER DATASET PATH
# ------------------------------
DATASET = r"E:\merged_waste_dataset"

# ------------------------------
# Determinism
# ------------------------------
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# ------------------------------
# Hyperparams
# ------------------------------
IMG_SIZE = 224
BATCH_SIZE = 32
LR = 1e-4
WEIGHT_DECAY = 1e-4
EPOCHS = 100
MIXUP_ALPHA = 0.4
MAX_PATIENCE = 10
NUM_WORKERS = 0  

# ------------------------------
# Dataset
# ------------------------------
class WasteDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.samples = []
        self.class_to_idx = {}

        classes = [d for d in os.listdir(root_dir) 
                   if os.path.isdir(os.path.join(root_dir, d))]
        classes.sort()

        for idx, cls in enumerate(classes):
            cls_folder = os.path.join(root_dir, cls)
            self.class_to_idx[cls] = idx
            for fname in os.listdir(cls_folder):
                if fname.lower().endswith(("jpg","jpeg","png","bmp","webp")):
                    self.samples.append((os.path.join(cls_folder, fname), idx))

        if len(self.samples) == 0:
            raise RuntimeError("No images found in dataset.")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        img = Image.open(path).convert("RGB")

        if self.transform:
            img = self.transform(img)
        else:
            img = transforms.Compose([
                transforms.Resize((IMG_SIZE, IMG_SIZE)),
                transforms.ToTensor()
            ])(img)

        return img, label

# ------------------------------
# Transforms & dataloader
# ------------------------------
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

train_dataset = WasteDataset(DATASET, transform=train_transform)
num_classes = len(train_dataset.class_to_idx)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS
)

print("Found", len(train_dataset), "images.")
print("Classes:", train_dataset.class_to_idx)

# ------------------------------
# SAME MODEL
# ------------------------------
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, in_channels, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv2 = nn.Conv2d(in_channels, in_channels, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(in_channels)

    def forward(self, x):
        identity = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += identity
        return F.relu(out)

class SEBlock(nn.Module):
    def __init__(self, in_channels, reduction=8):
        super().__init__()
        self.fc1 = nn.Linear(in_channels, in_channels//reduction)
        self.fc2 = nn.Linear(in_channels//reduction, in_channels)

    def forward(self, x):
        b, c, _, _ = x.size()
        y = F.adaptive_avg_pool2d(x, 1).view(b, c)
        y = F.relu(self.fc1(y))
        y = torch.sigmoid(self.fc2(y)).view(b, c, 1, 1)
        return x * y

class WasteNetR3(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.stem = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )
        self.layer1 = nn.Sequential(
            ResidualBlock(32),
            nn.MaxPool2d(2)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            ResidualBlock(64),
            SEBlock(64),
            nn.MaxPool2d(2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            ResidualBlock(128),
            SEBlock(128),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.stem(x)
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        return self.classifier(x)

model = WasteNetR3(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.5, patience=5)

# ------------------------------
# MixUp SAME
# ------------------------------
def mixup_data(x, y, alpha=MIXUP_ALPHA):
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(device)
    mixed_x = lam * x + (1 - lam) * x[index]
    return mixed_x, y, y[index], lam

# ------------------------------
# Training loop SAME
# ------------------------------
best_loss = 999999
patience_counter = 0

for epoch in range(EPOCHS):
    model.train()
    running = 0

    for imgs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
        imgs = imgs.to(device)
        labels = labels.to(device)

        # MixUp
        if random.random() < 0.5:
            imgs, y1, y2, lam = mixup_data(imgs, labels)
        else:
            y1 = labels
            y2 = labels
            lam = 1.0

        optimizer.zero_grad()

        # DirectML does NOT support autocast
        outputs = model(imgs)
        loss = lam * criterion(outputs, y1) + (1 - lam) * criterion(outputs, y2)

        loss.backward()
        optimizer.step()

        running += loss.item() * imgs.size(0)

    avg_loss = running / len(train_loader.dataset)
    print("Loss:", avg_loss)

    scheduler.step(avg_loss)

    if avg_loss < best_loss:
        best_loss = avg_loss
        torch.save(model.state_dict(), "best_model.pth")
        patience_counter = 0
        print("Model improved — saved.")
    else:
        patience_counter += 1
        if patience_counter >= MAX_PATIENCE:
            print("Early stopping triggered.")
            break

print("Training finished.")
# Out:
# Using DirectML: privateuseone:0
# Found 110753 images.
# Classes: {'1. Polythene': 0, '1. Sugarcane  husk': 1, '10.Mask': 2, '4. Glass': 3, '5. Wire': 4, '6. Glaves': 5, '7. Empty medicine packet': 6, 'Battery': 7, 'Keyboard': 8, 'Microwave': 9, 'Miscellanous_trash': 10, 'Mobile': 11, 'Mouse': 12, 'PCB': 13, 'Player': 14, 'Printer': 15, 'Television': 16, 'Textile Trash': 17, 'Washing Machine': 18, 'background_ground': 19, 'food_dishes': 20, 'food_items': 21, 'food_recyclable': 22, 'fruits_and_vegetables': 23, 'gauze': 24, 'glove_pair_latex': 25, 'glove_pair_nitrile': 26, 'glove_pair_surgery': 27, 'glove_single_latex': 28, 'glove_single_nitrile': 29, 'glove_single_surgery': 30, 'leaves_flowers': 31, 'medical_cap': 32, 'medical_glasses': 33, 'organic_waste': 34, 'paper_cardboard': 35, 'paper_waste': 36, 'plastic_containers_bottles_etc': 37, 'plastic_mixed': 38, 'recyclable': 39, 'recyclable_metal': 40, 'shoe_cover_pair': 41, 'shoe_cover_single': 42, 'test_tube': 43, 'urine_bag': 44, 'vegetables_and_fruits': 45}
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 193
#     190         x = self.layer3(x)
#     191         return self.classifier(x)
# --> 193 model = WasteNetR3(num_classes).to(device)
#     195 criterion = nn.CrossEntropyLoss()
#     196 optimizer = optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch\nn\modules\module.py:1174, in Module.to(self, *args, **kwargs)
#    1171         else:
#    1172             raise
# -> 1174 return self._apply(convert)
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch\nn\modules\module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch\nn\modules\module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch\nn\modules\module.py:805, in Module._apply(self, fn, recurse)
#     801 # Tensors stored in modules are graph leaves, and we don't want to
#     802 # track autograd history of `param_applied`, so we have to use
#     803 # `with torch.no_grad():`
#     804 with torch.no_grad():
# --> 805     param_applied = fn(param)
#     806 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     808 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch\nn\modules\module.py:1160, in Module.to.<locals>.convert(t)
#    1153     if convert_to_format is not None and t.dim() in (4, 5):
#    1154         return t.to(
#    1155             device,
#    1156             dtype if t.is_floating_point() or t.is_complex() else None,
#    1157             non_blocking,
#    1158             memory_format=convert_to_format,
#    1159         )
# -> 1160     return t.to(
#    1161         device,
#    1162         dtype if t.is_floating_point() or t.is_complex() else None,
#    1163         non_blocking,
#    1164     )
#    1165 except NotImplementedError as e:
#    1166     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# ModuleNotFoundError: No module named 'torch.privateuseone'

# %%
# !pip uninstall torch torchvision torchaudio torch-directml -y
# Out:
# Found existing installation: torch 2.4.1
# Uninstalling torch-2.4.1:
#   Successfully uninstalled torch-2.4.1
# Found existing installation: torchvision 0.19.1
# Uninstalling torchvision-0.19.1:
#   Successfully uninstalled torchvision-0.19.1
# Found existing installation: torchaudio 2.8.0
# Uninstalling torchaudio-2.8.0:
#   Successfully uninstalled torchaudio-2.8.0
# Found existing installation: torch-directml 0.2.5.dev240914
# Uninstalling torch-directml-0.2.5.dev240914:
#   Successfully uninstalled torch-directml-0.2.5.dev240914
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\HP\.conda\.conda\Lib\site-packages\~~rchvision'.
# You can safely remove it manually.

# %%
# !pip install torch torchvision torchaudio --upgrade
# !pip install torch-directml
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting torch
#   Using cached torch-2.8.0-cp39-cp39-win_amd64.whl.metadata (30 kB)
# Collecting torchvision
#   Using cached torchvision-0.23.0-cp39-cp39-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.8.0-cp39-cp39-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\.conda\.conda\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\.conda\.conda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\.conda\.conda\lib\site-packages (from jinja2->torch) (3.0.3)
# Using cached torch-2.8.0-cp39-cp39-win_amd64.whl (241.2 MB)
# Using cached torchvision-0.23.0-cp39-cp39-win_amd64.whl (1.6 MB)
# Using cached torchaudio-2.8.0-cp39-cp39-win_amd64.whl (2.5 MB)
# Installing collected packages: torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.8.0 torchaudio-2.8.0 torchvision-0.23.0
# Collecting torch-directml
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.8.0 requires torch==2.8.0, but you have torch 2.4.1 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached torch_directml-0.2.5.dev240914-cp39-cp39-win_amd64.whl.metadata (6.2 kB)
# Collecting torch==2.4.1 (from torch-directml)
#   Using cached torch-2.4.1-cp39-cp39-win_amd64.whl.metadata (27 kB)
# Collecting torchvision==0.19.1 (from torch-directml)
#   Using cached torchvision-0.19.1-cp39-cp39-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (4.15.0)
# Requirement already satisfied: sympy in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\.conda\.conda\lib\site-packages (from torch==2.4.1->torch-directml) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.19.1->torch-directml) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\.conda\.conda\lib\site-packages (from torchvision==0.19.1->torch-directml) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\.conda\.conda\lib\site-packages (from jinja2->torch==2.4.1->torch-directml) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\.conda\.conda\lib\site-packages (from sympy->torch==2.4.1->torch-directml) (1.3.0)
# Using cached torch_directml-0.2.5.dev240914-cp39-cp39-win_amd64.whl (9.0 MB)
# Using cached torch-2.4.1-cp39-cp39-win_amd64.whl (199.3 MB)
# Using cached torchvision-0.19.1-cp39-cp39-win_amd64.whl (1.3 MB)
# Installing collected packages: torch, torchvision, torch-directml
#
#   Attempting uninstall: torch
#
#     Found existing installation: torch 2.8.0
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#     Uninstalling torch-2.8.0:
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#       Successfully uninstalled torch-2.8.0
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#   Attempting uninstall: torchvision
#    ---------------------------------------- 0/3 [torch]
#     Found existing installation: torchvision 0.23.0
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#     Uninstalling torchvision-0.23.0:
#    ------------- -------------------------- 1/3 [torchvision]
#       Successfully uninstalled torchvision-0.23.0
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torch-directml]
#    ---------------------------------------- 3/3 [torch-directml]
#
# Successfully installed torch-2.4.1 torch-directml-0.2.5.dev240914 torchvision-0.19.1

# %%
import torch
import torch_directml

device = torch_directml.device()
x = torch.randn(2, 2, device=device)
print(x.device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 import torch_directml
#       4 device = torch_directml.device()
#       5 x = torch.randn(2, 2, device=device)
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch_directml\__init__.py:27
#      24 from .functions import *
#      26 # # Register backend to support AMP
# ---> 27 class PrivateUse1Module:
#      28     @staticmethod
#      29     def is_available() -> bool:
#      30         r"""Returns a bool indicating if DML is currently available."""
#
# File c:\Users\HP\.conda\.conda\lib\site-packages\torch_directml\__init__.py:74, in PrivateUse1Module()
#      69 @staticmethod
#      70 def disable_tiled_resources(is_disabled):
#      71     torch_directml_native.disable_tiled_resources(is_disabled)
#      73 @staticmethod
# ---> 74 def has_float64_support(device_id = default_device()):
#      75     return torch_directml_native.has_float64_support(device_id)
#      77 @staticmethod
#      78 def gpu_memory(device_id = default_device(), mb_per_tile = 1):
#
# TypeError: 'staticmethod' object is not callable
